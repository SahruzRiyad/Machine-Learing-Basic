# %%
import numpy as np
from matplotlib import pyplot as plt

tf = np.array([True , False])
dataset = np.empty((1000,4) , dtype ='O')
dataset.shape
# Out:
# (1000, 4)

# %%
dataset[:,:1] = np.random.randint(0,30,1000).reshape(1000,1)
dataset[:,1:2] = np.random.choice(tf,1000).reshape(1000,1)
dataset[:,2:3] = np.random.choice(tf,1000).reshape(1000,1)
max_salary = 1000000
for i in range(0,1000):
    dataset[i][3] = (max_salary + dataset[i][1] * 1000 + dataset[i][2] * 2000) / (31-dataset[i][0])
dataset
# Out:
# array([[18, False, False, 76923.07692307692],
#        [16, True, True, 66866.66666666667],
#        [5, False, False, 38461.53846153846],
#        ...,
#        [7, True, False, 41708.333333333336],
#        [4, False, True, 37111.11111111111],
#        [5, True, False, 38500.0]], dtype=object)

# %%
dataset.columns = ['Experience' , 'Front_End' , 'Back_End' , 'Salary']
dataset
# Out:
#     Experience Front_End Back_End         Salary
# 0           18     False    False   76923.076923
# 1           16      True     True   66866.666667
# 2            5     False    False   38461.538462
# 3           20      True     True   91181.818182
# 4           25      True     True  167166.666667
# ..         ...       ...      ...            ...
# 995         13      True    False   55611.111111
# 996          7     False    False   41666.666667
# 997          7      True    False   41708.333333
# 998          4     False     True   37111.111111
# 999          5      True    False        38500.0
#
# [1000 rows x 4 columns]

# %%
plt.plot(dataset.Experience)
plt.show()

# %%
plt.plot(dataset.Front_End)
plt.show()

# %%
plt.plot(dataset.Back_End)
plt.show()

# %%
plt.scatter(dataset.Experience,dataset.Salary , marker = '*' , color = 'red')
plt.xlabel('Experience');
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.scatter(dataset.Front_End,dataset.Salary , marker = '.' , color = 'blue')
plt.xlabel('Front_End');
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.scatter(dataset.Back_End,dataset.Salary , marker = 'o' , color = 'green')
plt.xlabel('Back_End');
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')
